# %% [markdown]
# <a href="https://colab.research.google.com/github/DDricko/DDricko/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1. Importando bibliotecas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader.data as web

# !pip install yfinance --upgrade --no-cache-dir
import yfinance as yf
yf.pdr_override()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# # 2. Obtendo os dados do mercado

# %%
litecoin = web.get_data_yahoo('LTC-USD')
litecoin.head()
litecoin.tail()
litecoin["Close"].plot(figsize=(22,8))
# Out:
# [*********************100%***********************]  1 of 1 completed
